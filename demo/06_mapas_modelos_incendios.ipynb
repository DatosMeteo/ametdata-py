# %% [markdown]
# # Mapas, Modelos Numéricos e Incendios
#
# Productos de análisis, mapas previstos y modelos meteorológicos numéricos.
#
# **Endpoints cubiertos:**
# - Mapas de análisis y significativos
# - Modelos numéricos: AESPOL, AEWAM, Harmonie (Península y Canarias)
# - Mapas de riesgo de incendios forestales (estimado y previsto)

# %%
# Instala el paquete (solo la primera vez)
# !pip install -q aemetdata nest_asyncio

# -- API Key ---------------------------------------------------------
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0"

# En Google Colab guarda tu clave como secreto con nombre AEMET_API_KEY
try:
    from google.colab import userdata
    API_KEY = userdata.get("AEMET_API_KEY") or API_KEY
except Exception:
    pass

import nest_asyncio; nest_asyncio.apply()
import pandas as pd
print(f"Listo. API key: {API_KEY[:8]}...")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Listo. API key: eyJhbGci...

# %% [markdown]
# ## 1. Mapas de análisis

# %%
from aemetdata.mapas import analisis_ultimo

resp_analisis = await analisis_ultimo([API_KEY])
print("Mapa de analisis (ultima pasada):")
print(resp_analisis)
# Out:
# Mapa de analisis (ultima pasada):
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7007ca6c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/6b261cd4'}

# %% [markdown]
# ## 2. Mapas significativos
#
# Mapas de tiempo significativo previsto. Ámbito: `nacional` o `ccaa`. Periodo `dia`: `0-12` o `12-24`.

# %%
from aemetdata.mapas import mapas_significativos

resp_sig = await mapas_significativos("2026-05-15", "nacional", "0-12", [API_KEY])
print("Mapa significativo nacional 0-12h:")
print(resp_sig)
# Out:
# Mapa significativo nacional 0-12h:
# {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}

# %% [markdown]
# ## 3. Mapas previstos

# %%
from aemetdata.mapas import mapas_previstos

resp_previstos = await mapas_previstos("12", [API_KEY])
print("Mapas previstos alcance=12:")
print(resp_previstos)
# Out:
# Mapas previstos alcance=12:
# {'descripcion': 'Debe introducir un alcance correcto.', 'estado': 404}

# %% [markdown]
# ## 4. Modelos numéricos
#
# ### 4.1 AESPOL — Oleaje Atlántico Norte
#
# Parámetros: `hs` (altura ola), `theta0` (dirección media), `tmm10` (periodo medio).

# %%
from aemetdata.modelos import aespol

resp_aespol = await aespol(pasada="00", alcance="12", parametro="hs", api_keys=[API_KEY])
print("Modelo AESPOL (hs, pasada 00, alcance 12):")
print(resp_aespol)
# Out:
# Modelo AESPOL (hs, pasada 00, alcance 12):
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/749eca30', 'metadatos': 'https://opendata.aemet.es/opendata/sh/41910905'}

# %% [markdown]
# ### 4.2 AEWAM — Oleaje Atlántico
#
# Parámetros: `shts`, `shww`, `swh`, `mdts`, `mdww`, `mwd`, `mpts`, `mpww`, `mwp`.

# %%
from aemetdata.modelos import aewam

resp_aewam = await aewam(pasada="00", alcance="24", parametro="swh", api_keys=[API_KEY])
print("Modelo AEWAM (swh, pasada 00, alcance 24):")
print(resp_aewam)
# Out:
# Modelo AEWAM (swh, pasada 00, alcance 24):
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/69fe2ad5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/c35490ab'}

# %% [markdown]
# ### 4.3 Harmonie — Modelo numérico de alta resolución
#
# Parámetros más habituales: `33` (viento), `61` (precipitación), `11` (temperatura 2m), `228` (humedad relativa).
#
# Pasadas: `00`, `06`, `12`, `18`. Formatos: `grib` o `netcdf`.

# %%
from aemetdata.modelos import harmonie_peninsula

resp_harm = await harmonie_peninsula(
    pasada="00", alcance="24", parametro="11", formato="grib", api_keys=[API_KEY]
)
print("Harmonie Peninsula (T2m, pasada 00, alcance 24, grib):")
print(resp_harm)
# Out:
# Harmonie Peninsula (T2m, pasada 00, alcance 24, grib):
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/fe259d2c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/f9d5795c'}

# %%
from aemetdata.modelos import harmonie_canarias

resp_harm_can = await harmonie_canarias(
    pasada="12", alcance="48", parametro="33", formato="netcdf", api_keys=[API_KEY]
)
print("Harmonie Canarias (viento, pasada 12, alcance 48, netcdf):")
print(resp_harm_can)
# Out:
# Harmonie Canarias (viento, pasada 12, alcance 48, netcdf):
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/84eff448', 'metadatos': 'https://opendata.aemet.es/opendata/sh/f9d5795c'}

# %% [markdown]
# ## 5. Riesgo de incendios forestales
#
# Áreas: `p` (Península), `b` (Baleares), `c` (Canarias).

# %%
from aemetdata.incendios import mapa_riesgo_estimado, mapa_riesgo_previsto, AREAS_INCENDIOS

print("Areas disponibles:", AREAS_INCENDIOS)

resp_estimado = await mapa_riesgo_estimado("p", [API_KEY])
print("\nRiesgo estimado Peninsula:")
print(resp_estimado)
# Out:
# Areas disponibles: {'p': 'Peninsula', 'b': 'Baleares', 'c': 'Canarias'}
# Riesgo estimado Peninsula:
# {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}

# %%
# Riesgo previsto para manana (dia=1)
resp_previsto = await mapa_riesgo_previsto("1", "p", [API_KEY])
print("Riesgo previsto manana Peninsula:")
print(resp_previsto)
# Out:
# Riesgo previsto manana Peninsula:
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/afb63705', 'metadatos': 'https://opendata.aemet.es/opendata/sh/fa09a9f6'}

# %%
from aemetdata.incendios import riesgo_raster

resp_raster = await riesgo_raster([API_KEY])
print("Raster de riesgo de incendios:")
print(resp_raster)
# Out:
# Raster de riesgo de incendios:
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/eff032dc', 'metadatos': 'https://opendata.aemet.es/opendata/sh/227dd3e2'}
