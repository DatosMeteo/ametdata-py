# %% [markdown]
# # Predicciones Meteorológicas
#
# Descarga de predicciones de AEMET a distintas escalas espaciales y temporales.
#
# **Endpoints cubiertos:**
# - Predicción nacional (hoy, mañana, pasado mañana, medio plazo, tendencia)
# - Predicción por CCAA y provincia
# - Predicción específica: municipio (diaria y horaria), playa, montaña
# - UVI y nivológica
# - Predicción marítima (altamar y costera)

# %%
# Instala el paquete (solo la primera vez)
# !pip install -q aemetdata nest_asyncio

# -- API Key ---------------------------------------------------------
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0"

# En Google Colab guarda tu clave como secreto con nombre AEMET_API_KEY
try:
    from google.colab import userdata
    API_KEY = userdata.get("AEMET_API_KEY") or API_KEY
except Exception:
    pass

import nest_asyncio; nest_asyncio.apply()
import pandas as pd
print(f"Listo. API key: {API_KEY[:8]}...")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Listo. API key: eyJhbGci...

# %% [markdown]
# ## 1. Predicción nacional

# %%
from aemetdata.prediccion import nacional_hoy, nacional_manana, nacional_pasadomanana
from aemetdata.utils.suport_functions import AemetError

try:
    pred_hoy = await nacional_hoy([API_KEY])
    print(f"Prediccion nacional hoy: {len(pred_hoy)} registros")
    display(pd.DataFrame(pred_hoy))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
    pred_hoy = []

try:
    pred_manana = await nacional_manana([API_KEY])
    print(f"Prediccion nacional manana: {len(pred_manana)} registros")
    display(pd.DataFrame(pred_manana))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
    pred_manana = []

try:
    pred_pasado = await nacional_pasadomanana([API_KEY])
    print(f"Prediccion nacional pasado manana: {len(pred_pasado)} registros")
    display(pd.DataFrame(pred_pasado))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Endpoint no disponible: Respuesta no es JSON válido (pred_nacional_hoy): Expecting value: line 1 column 1 (char 0)
# Endpoint no disponible: Respuesta no es JSON válido (pred_nacional_manana): Expecting value: line 1 column 1 (char 0)
# Endpoint no disponible: Respuesta no es JSON válido (pred_nacional_pasadomanana): Expecting value: line 1 column 1 (char 0)

# %%
# pred_manana ya obtenida en la celda anterior
if pred_manana:
    print(f"Prediccion nacional manana: {len(pred_manana)} registros")
    pd.DataFrame(pred_manana)
else:
    print("Sin datos de prediccion nacional manana")
# Out:
# Sin datos de prediccion nacional manana

# %%
from aemetdata.prediccion import nacional_medioplazo, nacional_tendencia

try:
    pred_mplazo = await nacional_medioplazo([API_KEY])
    print(f"Prediccion medio plazo: {len(pred_mplazo)} registros")
    display(pd.DataFrame(pred_mplazo))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Endpoint no disponible: Respuesta no es JSON válido (pred_nacional_medioplazo): Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 2. Predicción por CCAA
#
# Códigos de CCAA más habituales: `79` = Cataluña, `61` = Andalucía, `83` = Madrid, `73` = Comunitat Valenciana.

# %%
from aemetdata.prediccion import ccaa_hoy, ccaa_manana, ccaa_medioplazo

try:
    pred_ccaa = await ccaa_hoy("83", [API_KEY])  # Madrid
    print(f"Prediccion CCAA Madrid hoy: {len(pred_ccaa)} registros")
    display(pd.DataFrame(pred_ccaa))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
    pred_ccaa = []
# Out:
# Endpoint no disponible: Error en AEMET [pred_ccaa_hoy_83]: No hay datos que satisfagan esos criterios (estado: 404)

# %%
try:
    pred_ccaa_mplazo = await ccaa_medioplazo("83", [API_KEY])
    print(f"Prediccion CCAA Madrid medio plazo: {len(pred_ccaa_mplazo)} registros")
    display(pd.DataFrame(pred_ccaa_mplazo))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Endpoint no disponible: Error en AEMET [pred_ccaa_medioplazo_83]: No hay datos que satisfagan esos criterios (estado: 404)

# %% [markdown]
# ## 3. Predicción por provincia
#
# Código de provincia: `28` = Madrid, `08` = Barcelona, `41` = Sevilla.

# %%
from aemetdata.prediccion import provincia_hoy, provincia_manana

try:
    pred_prov = await provincia_hoy("28", [API_KEY])
    print(f"Prediccion provincia Madrid hoy: {len(pred_prov)} registros")
    display(pd.DataFrame(pred_prov))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Endpoint no disponible: Respuesta no es JSON válido (pred_provincia_hoy_28): Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 4. Predicción específica por municipio
#
# El código de municipio es el INE de 5 dígitos: `28079` = Madrid, `08019` = Barcelona, `41091` = Sevilla.

# %%
from aemetdata.prediccion import municipio_diaria
from aemetdata.utils.suport_functions import AemetError

try:
    pred_mun_d = await municipio_diaria("28079", [API_KEY])
    print(f"Prediccion diaria Madrid: {len(pred_mun_d)} registros")
    display(pd.DataFrame(pred_mun_d))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Prediccion diaria Madrid: 1 registros
#                                               origen            elaborado  \
# 0  {'productor': 'Agencia Estatal de Meteorología...  2026-05-16T13:08:08
#
#    nombre provincia                                         prediccion     id  \
# 0  Madrid    Madrid  {'dia': [{'probPrecipitacion': [{'value': 0, '...  28079
#
#    version
# 0      1.0

# %%
from aemetdata.prediccion import municipio_horaria

try:
    pred_mun_h = await municipio_horaria("28079", [API_KEY])
    print(f"Prediccion horaria Madrid: {len(pred_mun_h)} registros")
    display(pd.DataFrame(pred_mun_h))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 2 para JSON (pred_municipio_horaria_28079), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 2 (pred_municipio_horaria_28079): Remote end closed connection without response
# httpx disconnect intento 3 para JSON (pred_municipio_horaria_28079), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 3 (pred_municipio_horaria_28079): Remote end closed connection without response
# Endpoint no disponible: Error descargando JSON (pred_municipio_horaria_28079): Remote end closed connection without response

# %% [markdown]
# ## 5. Predicción de playa
#
# El código de playa se puede consultar en la web de AEMET o en el maestro de municipios.

# %%
from aemetdata.prediccion import playa

# 0304201001 = Playa de la Barceloneta (Barcelona)
try:
    pred_playa = await playa("0304201001", [API_KEY])
    print(f"Prediccion playa: {len(pred_playa)} registros")
    display(pd.DataFrame(pred_playa))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [pred_playa_0304201001], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_playa_0304201001]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_playa_0304201001], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_playa_0304201001]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_playa_0304201001], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_playa_0304201001]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_playa_0304201001], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_playa_0304201001]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_playa_0304201001], reintentando con urllib: Server disconnected without sending a response.
# ...

# %% [markdown]
# ## 6. UVI (Índice Ultravioleta)

# %%
from aemetdata.prediccion import uvi

# dia: '0' = hoy, '1' = manana, '2' = pasado, '3' = en 3 dias
try:
    pred_uvi = await uvi("0", [API_KEY])
    print(f"Prediccion UVI hoy: {len(pred_uvi)} registros")
    display(pd.DataFrame(pred_uvi).head(10))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [pred_uvi_0], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_uvi_0]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_uvi_0], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_uvi_0]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_uvi_0], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_uvi_0]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_uvi_0], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_uvi_0]: Remote end closed connection without response
# httpx disconnect clave 1 [pred_uvi_0], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_uvi_0]: Remote end closed connection without response
# ...

# %% [markdown]
# ## 7. Predicción marítima

# %%
from aemetdata.prediccion import maritima_costera, maritima_altamar

# Costas: '101' = Costa Cantabrica occidental, '121' = Costa Mediterranea nordeste...
try:
    pred_costera = await maritima_costera("101", [API_KEY])
    print(f"Prediccion maritima costera 101: {len(pred_costera)} registros")
    display(pd.DataFrame(pred_costera))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [pred_maritima_costera_101], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [pred_maritima_costera_101]: Remote end closed connection without response
# Endpoint no disponible: Error en AEMET [pred_maritima_costera_101]: El valor del campo 'costa' solo puede tomar los valores 40, 41, 42, 43, 44, 45, 46, 47 (estado: 404)

# %%
# Alta mar
try:
    pred_altamar = await maritima_altamar("11", [API_KEY])
    print(f"Prediccion altamar 11: {len(pred_altamar)} registros")
    display(pd.DataFrame(pred_altamar))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Endpoint no disponible: Error en AEMET [pred_maritima_altamar_11]: El valor del campo 'area' solo puede tomar los valores 0, 1, 2 (estado: 404)

# %% [markdown]
# ## 8. Predicción nivológica

# %%
from aemetdata.prediccion import nivologica

# Zonas: 'pir' = Pirineos, 'can' = Cordillera Cantabrica, 'sib' = Sistema Iberica
try:
    pred_nivo = await nivologica("pir", [API_KEY])
    print(f"Prediccion nivologica Pirineos: {len(pred_nivo)} registros")
    display(pd.DataFrame(pred_nivo))
except AemetError as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [pred_nivologica_pir], reintentando con urllib: Server disconnected without sending a response.
# Endpoint no disponible: Error en AEMET [pred_nivologica_pir]: Error en Predicciones Especificas Controller getPredNivologica: el valor del parametro solo puede ser 0,1 (estado: 404)
