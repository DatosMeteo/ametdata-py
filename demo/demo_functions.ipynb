# %% [markdown]
# # Demo de funciones AEMET
#
# Notebook de acceso rápido a todos los módulos del paquete `aemetdata`.
# Puede ejecutarse directamente en **Google Colab** o cualquier entorno Jupyter.

# %% [markdown]
# ## 1. Import Required Libraries and Load Functions

# %%
# Instala el paquete (solo la primera vez)
# !pip install -q aemetdata nest_asyncio

# -- API Key ---------------------------------------------------------
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0"

# En Google Colab guarda tu clave como secreto con nombre AEMET_API_KEY
try:
    from google.colab import userdata
    API_KEY = userdata.get("AEMET_API_KEY") or API_KEY
except Exception:
    pass

import nest_asyncio; nest_asyncio.apply()
import pandas as pd
print(f"Listo. API key: {API_KEY[:8]}...")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Listo. API key: eyJhbGci...

# %% [markdown]
# ## 2. Avisos

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.avisos import avisos_cap_ultimo_area
    
    archivos = await avisos_cap_ultimo_area("61", [API_KEY])
    print(f"Archivos CAP descargados: {list(archivos.keys())[:3]}")
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Error con clave 1 [avisos_cap_ultimo_61]:
# httpx disconnect clave 1 [avisos_cap_ultimo_61], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_ultimo_61]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_ultimo_61], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_ultimo_61]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_ultimo_61], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_ultimo_61]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_ultimo_61], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_ultimo_61]: Remote end closed connection without response
# Endpoint no disponible: No se pudo realizar la solicitud 'avisos_cap_ultimo_61' tras 5 ciclos.

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.avisos import avisos_cap_archivo
    
    archivos_hist = await avisos_cap_archivo("2026-05-13", "2026-05-15", [API_KEY])
    print(f"Archivos en el rango: {len(archivos_hist)}")
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [avisos_cap_archivo_20260513], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260513]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260513], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260513]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260513], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260513]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260513], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260513]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260513], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260513]: Remote end closed connection without response
# Error en avisos CAP para 2026-05-13: No se pudo realizar la solicitud 'avisos_cap_archivo_20260513' tras 5 ciclos.
# httpx disconnect clave 1 [avisos_cap_archivo_20260514], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260514]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260514], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260514]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260514], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260514]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260514], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [avisos_cap_archivo_20260514]: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260514], reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect para archivo, reintentando con urllib: Server disconnected without sending a response.
# Error en avisos CAP para 2026-05-14: Error descargando archivo: Remote end closed connection without response
# httpx disconnect clave 1 [avisos_cap_archivo_20260515], reintentando con urllib: Server disconnected without sending a response.
# Archivos en el rango: 1

# %% [markdown]
# ## 3. Climatología

# %% [markdown]
# ### 3.1 Climatología mensual

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.climatologia import datos_mensuales
    resultado = await datos_mensuales(["3195","3129"], 2020, 2024, [API_KEY])
    print(f"Tipo: {type(resultado)}")
    display(pd.DataFrame(resultado))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [clima_mensual_3195_2020_2022], reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect clave 1 [clima_mensual_3195_2023_2024], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [clima_mensual_3195_2023_2024]: Remote end closed connection without response
# httpx disconnect clave 1 [clima_mensual_3129_2020_2022], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [clima_mensual_3129_2020_2022]: Remote end closed connection without response
# httpx disconnect clave 1 [clima_mensual_3129_2023_2024], reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect intento 1 para JSON (clima_mensual_3129_2023_2024), reintentando con urllib: Server disconnected without sending a response.
# Tipo: <class 'list'>
#     indicativo         p_max   hr n_gra n_fog tm_min        ta_max ts_min  \
# 0         3195      24.2(20)   61     0     0    9.2      25.4(09)   14.5
# 1         3195      20.0(06)   79     0     3    8.1      19.4(01)   11.5
# 2         3195       4.5(07)   74     0     0    4.3      15.0(11)   11.9
# 3         3195  37.8(31/may)  NaN     1     6   11.1  39.4(27/jul)   25.4
# 4         3195       5.4(24)   66     0     1    3.6      15.7(31)    9.9
# ..         ...           ...  ...   ...   ...    ...           ...    ...
# 125       3129       5.7(05)   42     0     1    9.4      35.7(30)   15.4
# 126       3129      19.3(09)   43     0     0   14.8      36.7(25)   20.1
# 127       3129       0.0(--)   28     0     0   18.8      41.1(24)   23.5
# 128       3129       7.3(31)   33     0     0   19.8      40.4(09)   22.9
# 129       3129      25.3(19)   47     0     0   13.3      32.9(02)   19.9
#
#     nt_30 np_100  ... n_nub nw_91 w_rec nv_1000 evap w_med nv_0100  inso  \
# 0       0      1  ...   NaN   NaN   NaN     NaN  NaN   NaN     NaN   NaN
# 1       0      2  ...   NaN   NaN   NaN     NaN  NaN   NaN     NaN   NaN
# 2       0      0  ...   NaN   NaN   NaN     NaN  NaN   NaN     NaN   NaN
# 3      84     13  ...   NaN   NaN   NaN     NaN  NaN   NaN     NaN   NaN
# 4       0      0  ...     9     0   160       1  358     6       0   NaN
# ..    ...    ...  ...   ...   ...   ...     ...  ...   ...     ...   ...
# 125     7      0  ...    28     0   265       0  NaN    13       0   9.9
# 126    15      1  ...    18     0   260       0  NaN    12       0   9.1
# 127    31      0  ...     9     0   257       0  NaN    12       0  12.7
# 128    29      0  ...     9     0   220       0  NaN    10       0  10.5
# 129     8      1  ...    17     0   242       0  NaN    11       0   8.9
#
#     p_sol  glo
# 0     NaN  NaN
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# ..    ...  ...
# 125    69  NaN
# 126    60  NaN
# 127    86  NaN
# 128    77  NaN
# 129    72  NaN
#
# [130 rows x 43 columns]

# %% [markdown]
# ### 3.2 Climatología diaria

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.climatologia import datos_diarios
    resultado = await datos_diarios(["3195","3129"], '2022-01-01', '2022-08-10', [API_KEY])
    print(f'Tipo: {type(resultado)}')
    display(pd.DataFrame(resultado))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [clima_diario_3195_2022-01-01_2022-06-30], reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect intento 1 para JSON (clima_diario_3195_2022-07-01_2022-08-10), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 1 (clima_diario_3195_2022-07-01_2022-08-10): Remote end closed connection without response
# httpx disconnect intento 1 para JSON (clima_diario_3129_2022-07-01_2022-08-10), reintentando con urllib: Server disconnected without sending a response.
# Tipo: <class 'list'>
#           fecha indicativo             nombre provincia altitud  tmed prec  \
# 0    2022-01-01       3195     MADRID, RETIRO    MADRID     667  11,1  0,0
# 1    2022-01-02       3195     MADRID, RETIRO    MADRID     667   9,8  0,0
# 2    2022-01-03       3195     MADRID, RETIRO    MADRID     667   9,7  0,0
# 3    2022-01-04       3195     MADRID, RETIRO    MADRID     667   8,6  7,3
# 4    2022-01-05       3195     MADRID, RETIRO    MADRID     667   6,6  5,0
# ..          ...        ...                ...       ...     ...   ...  ...
# 438  2022-08-06       3129  MADRID AEROPUERTO    MADRID     609  29,1  0,0
# 439  2022-08-07       3129  MADRID AEROPUERTO    MADRID     609  29,0  0,0
# 440  2022-08-08       3129  MADRID AEROPUERTO    MADRID     609  28,4  0,0
# 441  2022-08-09       3129  MADRID AEROPUERTO    MADRID     609  29,4  0,0
# 442  2022-08-10       3129  MADRID AEROPUERTO    MADRID     609  31,4  0,0
#
#      tmin horatmin  tmax  ... hrMedia hrMax horaHrMax hrMin horaHrMin  dir  \
# 0     5,5    07:10  16,7  ...      51    85     02:10    29     13:40  NaN
# 1     5,1    07:40  14,5  ...      67    87     23:40    51     15:50  NaN
# 2     5,6    07:30  13,8  ...      81    96     23:50    68     13:50  NaN
# 3     5,2    05:30  12,1  ...      86    99    Varias    68    Varias  NaN
# 4     4,3    04:20   8,9  ...      77    99     20:50    54     14:10  NaN
# ..    ...      ...   ...  ...     ...   ...       ...   ...       ...  ...
# 438  20,8    05:34  37,4  ...      26    52     05:59    15     16:49   24
# 439  21,3    05:06  36,7  ...      27    56     05:58    14     19:00   22
# 440  19,8    04:04  37,1  ...      26    54     05:24    13     18:26   22
# 441  20,8    05:41  38,1  ...      26    47     06:10    15     16:51   21
# 442  25,0    05:46  37,7  ...      27    46     05:47    17     14:46   14
#
#     velmedia racha horaracha   sol
# 0        NaN   NaN       NaN   NaN
# 1        NaN   NaN       NaN   NaN
# 2        NaN   NaN       NaN   NaN
# 3        NaN   NaN       NaN   NaN
# 4        NaN   NaN       NaN   NaN
# ..       ...   ...       ...   ...
# 438      2,8  10,8     15:52  12,5
# 439      3,1  14,4     14:44  12,7
# 440      2,5  11,4     14:26  12,6
# 441      1,9  11,4     14:55  12,2
# 442      3,3  12,5     21:13   9,4
#
# [443 rows x 25 columns]

# %% [markdown]
# ### 3.3 Valores normales
# Valores climatológicos normales (periodo 1991-2020) para la estación pasada por parámetro. Periodicidad: 1 vez al día.

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.climatologia import datos_normales
    resultado_normales = await datos_normales(["3195","3129"], [API_KEY])
    print(f"Tipo: {type(resultado_normales)}")
    import pandas as pd
    display(pd.DataFrame(resultado_normales))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 1 para JSON (clima_normales_3195), reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect clave 1 [clima_normales_3129], reintentando con urllib: Server disconnected without sending a response.
# Tipo: <class 'list'>
#    indicativo w_racha_max np_010_n np_010_s q_max_s n_tor_n n_tor_s q_max_n  \
# 0        3195        23.3       30     3.61    4.09      30    0.25      30
# 1        3195        26.1       30     3.13    3.35      30    0.35      30
# 2        3195        23.3       30     4.29     3.7      30    0.72      29
# 3        3195        24.4       30      3.2    2.57      30     1.0      29
# 4        3195        21.4       30     3.98    2.71      30    2.23      29
# 5        3195        21.9       30     2.35    1.76      30    2.13      29
# 6        3195        28.1       30     1.61    1.81      30    1.67      29
# 7        3195        25.0       30      1.7     1.9      30    1.53      29
# 8        3195        23.1       30     2.29    2.06      30    1.07      29
# 9        3195        20.0       30     3.57    2.06      30     0.8      29
# 10       3195        23.9       30     4.37    2.98      30     0.0      30
# 11       3195        21.1       30     4.47    4.24      30    0.18      29
# 12       3195                   30    12.11    3.11      30    5.17      28
# 13       3129        25.8       30     3.77    4.19      30     0.0      30
# 14       3129        24.7       30     2.58    3.45      30    0.38      30
# 15       3129        28.9       30     3.78    3.33      30    0.63      30
# 16       3129        23.3       30     3.26    2.56      30    1.34      30
# 17       3129        25.8       30     3.63    2.55      30    2.22      30
# 18       3129        22.8       30     2.62    1.92      30    1.92      30
# 19       3129        40.8       30     1.81    1.76      30    1.98      30
# 20       3129        27.8       30     1.54    1.66      30     1.7      30
# 21       3129        25.3       30     1.68    1.86      30    1.22      30
# 22       3129        28.9       30     3.69    2.18      30    0.96      30
# 23       3129        28.6       30     3.96    2.92      30    0.35      30
# 24       3129        24.4       30     4.33    3.35      30    0.18      30
# 25       3129        32.5       30     12.3    2.58      30    5.61      30
#
#    tm_min_q4 tm_min_q1  ... n_nie_min nt_30_q4 q_med_q4 n_cub_md n_cub_mn  \
# 0        4.0       1.9  ...       0.0      0.0    947.8      8.7      9.0
# 1        5.4       2.5  ...       0.0      0.0    946.1      6.1      6.0
# 2        6.8       5.5  ...       0.0      0.0    942.9      6.4      5.5
# 3        9.3       6.9  ...       0.0      0.0    939.1      7.0      6.0
# 4       13.2      10.8  ...       0.0      5.0    939.7      6.1      6.0
# 5       17.4      15.5  ...       0.0     18.0    940.8      2.6      2.0
# 6       20.7      18.3  ...       0.0     30.0    940.3      0.5      0.0
# 7       20.3      18.7  ...       0.0     26.0    940.2      1.0      1.0
# 8       16.6      14.6  ...       0.0     10.2    941.6      2.8      3.0
# 9       12.3       9.8  ...       0.0      0.0    942.0      7.1      6.0
# 10       7.7       5.3  ...       0.0      0.0    943.0      7.6      8.0
# 11       4.9       2.8  ...       0.0      0.0    946.9      9.0      8.0
# 12      11.0      10.0  ...       0.0     84.0    941.0     65.6     63.0
# 13       1.9      -1.2  ...       0.0      0.0    957.2      8.5      8.0
# 14       2.7       0.0  ...       0.0      0.0    956.2      5.8      6.0
# 15       4.6       2.8  ...       0.0      0.0    952.5      6.1      6.0
# 16       7.2       5.0  ...       0.0      0.0    948.7      6.5      6.0
# 17      11.1       9.1  ...       0.0      7.0    949.2      5.6      6.0
# 18      15.5      13.4  ...       0.0     20.0    950.2      2.3      2.0
# 19      18.5      16.3  ...       0.0     30.0    949.8      0.4      0.0
# 20      17.9      16.4  ...       0.0     29.0    949.9      0.6      0.0
# 21      14.4      12.0  ...       0.0     14.4    951.1      2.7      2.5
# 22      10.0       7.8  ...       0.0      0.2    951.9      7.2      7.0
# 23       6.1       2.8  ...       0.0      0.0    953.0      7.6      8.0
# 24       3.2       0.3  ...       0.0      0.0    957.8      8.9      8.5
# 25       8.9       7.7  ...       0.0     93.4    950.8     62.1     63.0
#
#    ta_max_min np_010_max inso_md inso_mn  evap_mn
# 0        12.1       14.0                    314.0
# 1        14.0       13.0                    463.0
# 2        17.7       18.0     6.7     6.9    782.0
# 3        21.7       13.0                    839.0
# 4        26.0       19.0                   1031.0
# 5        30.6       10.0                   1586.0
# 6        35.0        8.0                   2001.0
# 7        34.0        7.0                   1872.0
# 8        29.4        8.0                   1178.0
# 9        22.2       16.0                    698.0
# 10       16.5       15.0                    375.0
# 11       13.4       17.0                    296.0
# 12       36.3       86.0                  11081.0
# 13       13.3       14.0     4.9     4.8
# 14       14.5       11.0     6.2     6.1
# 15       17.6       16.0     7.2     7.2
# 16       21.4       14.0     7.8     7.9
# 17       27.6       14.0     8.8     8.8
# 18       32.2       10.0    10.8    11.1
# 19       35.3        9.0    12.0    12.0
# 20       35.5        6.0    11.0    10.9
# 21       30.7        6.0     8.8     8.7
# 22       23.0       16.0     6.6     6.5
# 23       17.0       15.0     5.1     4.7
# 24       14.4       17.0     4.4     4.3
# 25       37.3       82.0     7.8     7.9
#
# [26 rows x 475 columns]

# %% [markdown]
# ### 3.4 Valores extremos
# Valores extremos para la estación  (precipitación, temperatura y viento). Periodicidad: 1 vez al día.

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.climatologia import datos_extremos
    resultado_extremos_T = await datos_extremos(["3195","3129"], [API_KEY], parametro="T")
    print(f"Tipo: {type(resultado_extremos_T)}")
    display(pd.DataFrame(resultado_extremos_T))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [clima_extremos_3195_T], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [clima_extremos_3195_T]: Remote end closed connection without response
# httpx disconnect clave 1 [clima_extremos_3195_T], reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect intento 1 para JSON (clima_extremos_3195_T), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 1 (clima_extremos_3195_T): Remote end closed connection without response
# httpx disconnect intento 2 para JSON (clima_extremos_3195_T), reintentando con urllib: Server disconnected without sending a response.
# httpx disconnect clave 1 [clima_extremos_3129_T], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [clima_extremos_3129_T]: Remote end closed connection without response
# Tipo: <class 'list'>
#   indicativo             nombre ubicacion  codigo  \
# 0       3195     MADRID, RETIRO    MADRID  023000
# 1       3129  MADRID AEROPUERTO    MADRID  023000
#
#                                               temMin  \
# 0  [-101, -91, -51, -16, 6, 44, 85, 92, 40, -4, -...
# 1  [-152, -148, -66, -40, -5, 39, 70, 74, 19, -24...
#
#                                               diaMin  \
# 0  [16, 12, 1, 13, 10, 3, 19, 30, 29, 8, 22, 26, 16]
# 1    [16, 5, 8, 11, 4, 3, 3, 30, 29, 31, 24, 16, 16]
#
#                                              anioMin mesMin  \
# 0  [1945, 1956, 2005, 1986, 1951, 1984, 1932, 193...      1
# 1  [1945, 1963, 2005, 1973, 1991, 1975, 1997, 197...      1
#
#                                               temMax  \
# 0  [199, 220, 267, 309, 355, 407, 407, 407, 389, ...
# 1  [209, 245, 271, 325, 365, 412, 422, 427, 402, ...
#
#                                              diaMax  ... mesMedBaja  \
# 0  [27, 28, 30, 28, 13, 28, 14, 14, 6, 6, 1, 1, 14]  ...          2
# 1  [27, 28, 31, 28, 13, 28, 14, 14, 8, 8, 1, 1, 14]  ...          1
#
#                                           temMedAlta  \
# 0  [84, 109, 147, 176, 206, 271, 298, 287, 242, 1...
# 1  [82, 101, 128, 165, 198, 261, 289, 281, 235, 1...
#
#                                          anioMedAlta mesMedAlta  \
# 0  [2024, 2020, 1997, 2026, 2022, 2025, 2015, 202...          7
# 1  [2016, 1990, 1997, 2026, 2022, 2025, 2022, 202...          7
#
#                                            temMedMin  \
# 0  [-16, -26, 4, 43, 63, 116, 147, 151, 113, 64, ...
# 1  [-38, -30, 1, 28, 58, 106, 132, 136, 97, 48, -...
#
#                                           anioMedMin mesMedMin  \
# 0  [1945, 1956, 1925, 1986, 1984, 1923, 1977, 193...         2
# 1  [1945, 1956, 1970, 1986, 1984, 1977, 1977, 198...        12
#
#                                            temMedMax  \
# 0  [121, 160, 209, 238, 272, 338, 368, 355, 303, ...
# 1  [132, 170, 221, 251, 279, 347, 377, 363, 319, ...
#
#                                           anioMedMax mesMedMax
# 0  [1983, 2000, 1997, 2023, 2015, 2025, 2022, 193...         7
# 1  [2008, 2000, 1997, 2023, 2022, 2025, 2022, 202...         7
#
# [2 rows x 24 columns]

# %% [markdown]
# ## 4. Observaciones
#
# Observaciones en tiempo real de todas las estaciones (últimas 24 h).

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.observaciones import todas, datos_estacion
    
    obs_todas = await todas([API_KEY])
    print(f"Estaciones con datos: {len(obs_todas)}")
    display(pd.DataFrame(obs_todas).head(10))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 1 para JSON (obs_todas), reintentando con urllib: Server disconnected without sending a response.
# Estaciones con datos: 9398
#    idema       lon                      fint  prec    alt  vmax   vv     dv  \
# 0  0009X  0.963335  2026-05-16T07:00:00+0000   0.0  406.0   7.8  4.1  259.0
# 1  0016A  1.163611  2026-05-16T07:00:00+0000   0.0   71.0   8.8  4.1  210.0
# 2  0034X  1.260838  2026-05-16T07:00:00+0000   0.0  233.0   NaN  NaN    NaN
# 3  0042Y  1.249167  2026-05-16T07:00:00+0000   0.0   55.0   3.2  1.1  233.0
# 4  0061X  1.519269  2026-05-16T07:00:00+0000   0.0  632.0   8.3  5.8  287.0
# 5  0066X  1.676942  2026-05-16T07:00:00+0000   0.0  177.0   3.2  1.0   75.0
# 6  0073X  1.852626  2026-05-16T07:00:00+0000   0.0   58.0   7.9  2.6   22.0
# 7   0076  2.069995  2026-05-16T07:00:00+0000   0.0    4.0   7.2  6.0  360.0
# 8  0092X  1.857494  2026-05-16T07:00:00+0000   0.0  682.0   4.4  1.5  223.0
# 9  0106X  1.872504  2026-05-16T07:00:00+0000   0.0  361.0   3.9  2.6   16.0
#
#          lat   dmax  ... pacutp  vvu  stdvvu  stddvu  dmaxu  tss20cm  geo925  \
# 0  41.213892  245.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 1  41.145000  240.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 2  41.293053    NaN  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 3  41.123892  285.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 4  41.417052  282.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 5  41.330279  100.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 6  41.243784   32.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 7  41.292781   10.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 8  42.101388   82.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 9  41.866387   12.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
#
#    geo850  nieve  geo700
# 0     NaN    NaN     NaN
# 1     NaN    NaN     NaN
# 2     NaN    NaN     NaN
# 3     NaN    NaN     NaN
# 4     NaN    NaN     NaN
# 5     NaN    NaN     NaN
# 6     NaN    NaN     NaN
# 7     NaN    NaN     NaN
# 8     NaN    NaN     NaN
# 9     NaN    NaN     NaN
#
# [10 rows x 39 columns]

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    # Observacion de Madrid Retiro (3195) y Salamanca (3129)
    obs = await datos_estacion(["3195", "3129"], [API_KEY])
    print(f"Registros: {len(obs)}")
    display(pd.DataFrame(obs))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 1 para JSON (obs_estacion_3129), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 1 (obs_estacion_3129): Remote end closed connection without response
# httpx disconnect intento 2 para JSON (obs_estacion_3129), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 2 (obs_estacion_3129): Remote end closed connection without response
# httpx disconnect intento 3 para JSON (obs_estacion_3129), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 3 (obs_estacion_3129): Remote end closed connection without response
# Endpoint no disponible: Error descargando JSON (obs_estacion_3129): Remote end closed connection without response

# %% [markdown]
# ## 5. Predicción
#
# Predicciones por municipio (diaria y horaria) y predicción nacional.

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.prediccion import municipio_diaria, municipio_horaria
    
    # 28079 = Madrid, 08019 = Barcelona, 41091 = Sevilla
    pred_diaria = await municipio_diaria("28079", [API_KEY])
    print(f"Prediccion diaria Madrid: {len(pred_diaria)} registros")
    display(pd.DataFrame(pred_diaria))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Prediccion diaria Madrid: 1 registros
#                                               origen            elaborado  \
# 0  {'productor': 'Agencia Estatal de Meteorología...  2026-05-16T13:08:08
#
#    nombre provincia                                         prediccion     id  \
# 0  Madrid    Madrid  {'dia': [{'probPrecipitacion': [{'value': 0, '...  28079
#
#    version
# 0      1.0

# %%
try:
    pred_horaria = await municipio_horaria("28079", [API_KEY])
    print(f"Prediccion horaria Madrid: {len(pred_horaria)} registros")
    display(pd.DataFrame(pred_horaria))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [pred_municipio_horaria_28079], reintentando con urllib: Server disconnected without sending a response.
# Prediccion horaria Madrid: 1 registros
#                                               origen            elaborado  \
# 0  {'productor': 'Agencia Estatal de Meteorología...  2026-05-16T13:08:08
#
#    nombre provincia                                         prediccion     id  \
# 0  Madrid    Madrid  {'dia': [{'estadoCielo': [{'value': '11', 'per...  28079
#
#   version
# 0     1.0

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.prediccion import nacional_hoy
    
    pred_nac = await nacional_hoy([API_KEY])
    print(f"Prediccion nacional hoy: {len(pred_nac)} registros")
    display(pd.DataFrame(pred_nac))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 1 para JSON (pred_nacional_hoy), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 1 (pred_nacional_hoy): Expecting value: line 1 column 1 (char 0)
# Endpoint no disponible: Respuesta no es JSON válido (pred_nacional_hoy): Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 6. Maestro de municipios
#
# Catálogo completo de municipios de España. Útil para obtener los códigos que necesitan las predicciones.

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.maestro import todos_municipios, municipio_por_nombre
    
    municipios = await todos_municipios([API_KEY])
    print(f"Total municipios: {len(municipios)}")
    display(pd.DataFrame(municipios).head(10))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect clave 1 [maestro_municipios], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [maestro_municipios]: Remote end closed connection without response
# httpx disconnect intento 1 para JSON (maestro_municipios), reintentando con urllib: Server disconnected without sending a response.
# urllib también falló intento 1 (maestro_municipios): Remote end closed connection without response
# httpx disconnect intento 2 para JSON (maestro_municipios), reintentando con urllib: Server disconnected without sending a response.
# Total municipios: 8122
#             latitud id_old                                                url  \
# 0  40º32'54.450744"  44004                                     ababuj-id44001
# 1  40º54'58.824504"  40004                                     abades-id40001
# 2   43º8'51.525564"  48010                   abadino-abadino-zelaieta-id48001
# 3  40º15'34.315272"  10004                                     abadia-id10001
# 4  43º21'46.874736"  27010                 abadin-abadin-o-provecende-id27001
# 5   42º37'23.69766"  09004                                     abajas-id09001
# 6   43º2'48.186348"  20010                               abaltzisketa-id20001
# 7  38º12'28.401012"  30010                                   abanilla-id30001
# 8   41º8'17.648448"  50003                                     abanto-id50001
# 9  43º18'38.977164"  48020  abanto-y-ciervana-abanto-zierbena-gallarta-id4...
#
#    latitud_dec altitud              capital num_hab zona_comarcal destacada  \
# 0  40.54845854    1372               Ababuj      65        624401         0
# 1  40.91634014     971               Abades     873        674001         0
# 2  43.14764599     144     Abadiño-Zelaieta    7504        754802         0
# 3  40.25953202     451               Abadía     324        701001         0
# 4  43.36302076     515  Abadín o Provecende    2646        712702         0
# 5  42.62324935     839               Abajas      29        670902         0
# 6  43.04671843     374         Abaltzisketa     329        752002         0
# 7  38.20788917     222             Abanilla    6435        733003         0
# 8  41.13823568     929               Abanto     113        625002         0
# 9  43.31082699     100             Gallarta    9688        754802         0
#
#                               nombre longitud_dec       id          longitud
# 0                             Ababuj  -0.80780117  id44001  -0º48'28.084212"
# 1                             Abades  -4.26787389  id40001   -4º16'4.346004"
# 2                            Abadiño  -2.60687319  id48001  -2º36'24.743484"
# 3                             Abadía  -5.97785806  id10001  -5º58'40.289016"
# 4                             Abadín  -7.47214495  id27001   -7º28'19.72182"
# 5                             Abajas  -3.58176303  id09001  -3º34'54.346908"
# 6                       Abaltzisketa  -2.10562430  id20001    -2º6'20.24748"
# 7                           Abanilla  -1.04259775  id30001     -1º2'33.3519"
# 8                             Abanto  -1.69921759  id50001  -1º41'57.183324"
# 9  Abanto y Ciérvana-Abanto Zierbena  -3.07319265  id48002    -3º4'23.49354"

# %%
try:
    busqueda = await municipio_por_nombre("Madrid", [API_KEY])
    print(f"Municipios con 'Madrid': {len(busqueda)}")
    display(pd.DataFrame(busqueda))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Error con clave 1 [maestro_municipio_nombre_Madrid]: Respuesta no JSON: 'text/plain;charset=ISO-8859-15'
# httpx disconnect clave 1 [maestro_municipio_nombre_Madrid], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [maestro_municipio_nombre_Madrid]: Respuesta inesperada (no dict): <class 'list'>
# httpx disconnect clave 1 [maestro_municipio_nombre_Madrid], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [maestro_municipio_nombre_Madrid]: Remote end closed connection without response
# httpx disconnect clave 1 [maestro_municipio_nombre_Madrid], reintentando con urllib: Server disconnected without sending a response.
# Error con clave 1 [maestro_municipio_nombre_Madrid]: Respuesta inesperada (no dict): <class 'list'>
# Error con clave 1 [maestro_municipio_nombre_Madrid]: Respuesta no JSON: 'text/plain;charset=ISO-8859-15'
# Endpoint no disponible: No se pudo realizar la solicitud 'maestro_municipio_nombre_Madrid' tras 5 ciclos.

# %% [markdown]
# ## 7. Radar e imágenes de satélite

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.redes import radar_nacional
    from IPython.display import Image, display
    
    img_radar = await radar_nacional([API_KEY])
    print(f"Radar nacional: {len(img_radar)} bytes")
    if img_radar:
        display(Image(data=img_radar))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# httpx disconnect intento 1 para binario (radar_nacional), reintentando con urllib: Server disconnected without sending a response.
# Radar nacional: 7617 bytes

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.imagenes import satelite_ndvi
    
    img_ndvi = await satelite_ndvi([API_KEY])
    print(f"NDVI satelite: {len(img_ndvi)} bytes")
    if img_ndvi:
        display(Image(data=img_ndvi))
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# NDVI satelite: 254069 bytes

# %% [markdown]
# ## 8. Avisos meteorológicos (CAP)

# %% [markdown]
# ## 9. Riesgo de incendios forestales

# %%
from aemetdata.utils.suport_functions import AemetError

try:
    from aemetdata.incendios import mapa_riesgo_estimado, mapa_riesgo_previsto
    
    resp_est = await mapa_riesgo_estimado("p", [API_KEY])
    print("Riesgo estimado Peninsula:", resp_est)
    
    resp_prev = await mapa_riesgo_previsto("1", "p", [API_KEY])
    print("Riesgo previsto manana Peninsula:", resp_prev)
except (AemetError, Exception) as e:
    print(f"Endpoint no disponible: {e}")
# Out:
# Riesgo estimado Peninsula: {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/f349cbab', 'metadatos': 'https://opendata.aemet.es/opendata/sh/fa09a9f6'}
# Riesgo previsto manana Peninsula: {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/afb63705', 'metadatos': 'https://opendata.aemet.es/opendata/sh/fa09a9f6'}
